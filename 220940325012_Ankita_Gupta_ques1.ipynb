# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing dataset
df=pd.read_csv(r'C:\Users\ankit\Machine Learning\end modeule exam\data_1.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.info()
# checking datatypes of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isna().sum()
# checking null values-- no null values are present
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.duplicated().sum()
#checking duplicate value--- 2 duplicates are present
# Out:
# 2

# %%
#dropping duplicate values
df=df.drop_duplicates()

# %%
# after dropping duplicates, againg checking rows and columns
df.shape
# Out:
# (299, 9)

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.tail()
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 296     city  2016           9.50           11.6       33988    Diesel
# 297     brio  2015           4.00            5.9       60000    Petrol
# 298     city  2009           3.35           11.0       87934    Petrol
# 299     city  2017          11.50           12.5        9000    Diesel
# 300     brio  2016           5.30            5.9        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0

# %%
df.describe(include='all')
# Out:
#        Car_Name         Year  Selling_Price  Present_Price     Kms_Driven  \
# count       299   299.000000     299.000000     299.000000     299.000000
# unique       98          NaN            NaN            NaN            NaN
# top        city          NaN            NaN            NaN            NaN
# freq         26          NaN            NaN            NaN            NaN
# mean        NaN  2013.615385       4.589632       7.541037   36916.752508
# std         NaN     2.896868       4.984240       8.567887   39015.170352
# min         NaN  2003.000000       0.100000       0.320000     500.000000
# 25%         NaN  2012.000000       0.850000       1.200000   15000.000000
# 50%         NaN  2014.000000       3.510000       6.100000   32000.000000
# 75%         NaN  2016.000000       6.000000       9.840000   48883.500000
# max         NaN  2018.000000      35.000000      92.600000  500000.000000
#
#        Fuel_Type Seller_Type Transmission       Owner
# ...

# %%
df.value_counts()
# Out:
# Car_Name           Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner
# 800                2003  0.35           2.28           127000      Petrol     Individual   Manual        0        1
# etios gd           2015  4.75           7.85           40000       Diesel     Dealer       Manual        0        1
# etios g            2014  4.75           6.76           40000       Petrol     Dealer       Manual        0        1
#                          4.10           6.80           39485       Petrol     Dealer       Manual        1        1
# etios cross        2015  4.50           7.70           40588       Petrol     Dealer       Manual        0        1
#                                                                                                                  ..
# Yamaha FZ S V 2.0  2015  0.55           0.84           58000       Petrol     Individual   Manual        0        1
# ...

# %%
df['Car_Name'].unique()
# Out:
# array(['ritz', 'sx4', 'ciaz', 'wagon r', 'swift', 'vitara brezza',
#        's cross', 'alto 800', 'ertiga', 'dzire', 'alto k10', 'ignis',
#        '800', 'baleno', 'omni', 'fortuner', 'innova', 'corolla altis',
#        'etios cross', 'etios g', 'etios liva', 'corolla', 'etios gd',
#        'camry', 'land cruiser', 'Royal Enfield Thunder 500',
#        'UM Renegade Mojave', 'KTM RC200', 'Bajaj Dominar 400',
#        'Royal Enfield Classic 350', 'KTM RC390', 'Hyosung GT250R',
#        'Royal Enfield Thunder 350', 'KTM 390 Duke ',
#        'Mahindra Mojo XT300', 'Bajaj Pulsar RS200',
#        'Royal Enfield Bullet 350', 'Royal Enfield Classic 500',
#        'Bajaj Avenger 220', 'Bajaj Avenger 150', 'Honda CB Hornet 160R',
#        'Yamaha FZ S V 2.0', 'Yamaha FZ 16', 'TVS Apache RTR 160',
#        'Bajaj Pulsar 150', 'Honda CBR 150', 'Hero Extreme',
#        'Bajaj Avenger 220 dtsi', 'Bajaj Avenger 150 street',
# ...

# %%
sns.boxplot(df.Selling_Price)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Selling_Price'>

# %%
sns.boxplot(df.Present_Price)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Present_Price'>

# %%
sns.boxplot(df.Kms_Driven)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Kms_Driven'>

# %%
sns.countplot('Selling_Price',data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Selling_Price', ylabel='count'>

# %%
sns.pairplot(df)

# %% [raw]
# * every year selling price is increasing

# %%
plt.xticks(rotation=90)
sns.countplot(df.Year, hue='Fuel_Type', data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %% [markdown]
# - we can see every year, petrol cars are increasing than diesel and CNG

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
sns.countplot(df.Transmission,data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Transmission', ylabel='count'>

# %% [markdown]
# - we can see, autumatic cars are in less quantity as compared to manual cars

# %%
sns.catplot(data=df, kind='strip', x='Transmission',y='Selling_Price')

# %% [markdown]
# Automatic cars have higher price.

# %%
df.drop(['Car_Name'],axis=1,inplace=True)
# we can drop car name as it has not much effect.
# Out:
# C:\Users\ankit\AppData\Local\Temp\ipykernel_13152\503214184.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Car_Name'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
# converting categoricall to numeric columns
df=pd.get_dummies(df)

# %%
df
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_CNG  \
# 0    2014           3.35           5.59       27000      0              0
# 1    2013           4.75           9.54       43000      0              0
# 2    2017           7.25           9.85        6900      0              0
# 3    2011           2.85           4.15        5200      0              0
# 4    2014           4.60           6.87       42450      0              0
# ..    ...            ...            ...         ...    ...            ...
# 296  2016           9.50          11.60       33988      0              0
# 297  2015           4.00           5.90       60000      0              0
# 298  2009           3.35          11.00       87934      0              0
# 299  2017          11.50          12.50        9000      0              0
# 300  2016           5.30           5.90        5464      0              0
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# ...

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(16,16))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df=df.drop(["Transmission_Automatic",'Fuel_Type_CNG'],axis=1)

# %%
df.shape
# Out:
# (299, 10)

# %%
#splitting the dataset into x and y column
x=df.drop('Selling_Price',axis=1)
y=df['Selling_Price']

# %%
x
# Out:
#      Year  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0    2014           5.59       27000      0                 0
# 1    2013           9.54       43000      0                 1
# 2    2017           9.85        6900      0                 0
# 3    2011           4.15        5200      0                 0
# 4    2014           6.87       42450      0                 1
# ..    ...            ...         ...    ...               ...
# 296  2016          11.60       33988      0                 1
# 297  2015           5.90       60000      0                 0
# 298  2009          11.00       87934      0                 0
# 299  2017          12.50        9000      0                 1
# 300  2016           5.90        5464      0                 0
#
#      Fuel_Type_Petrol  Seller_Type_Dealer  Seller_Type_Individual  \
# 0                   1                   1                       0
# 1                   0                   1                       0
# ...

# %%
y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 299, dtype: float64

# %%
#splitting the dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=1)

# %%
# performing preprocessing
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
x_train
# Out:
# array([[-1.22943462, -0.95438417, -0.25760084, ..., -1.40978722,
#          1.40978722,  0.37886762],
#        [ 0.46316258, -0.23391093,  0.05178264, ...,  0.7093269 ,
#         -0.7093269 ,  0.37886762],
#        [ 1.14020147, -0.43742605,  0.01531611, ...,  0.7093269 ,
#         -0.7093269 ,  0.37886762],
#        ...,
#        [-0.89091518, -0.24728054,  0.12250634, ...,  0.7093269 ,
#         -0.7093269 ,  0.37886762],
#        [ 0.46316258,  0.9247883 ,  0.7164238 , ...,  0.7093269 ,
#         -0.7093269 ,  0.37886762],
#        [ 0.80168202, -0.53695534, -0.65958794, ...,  0.7093269 ,
#         -0.7093269 ,  0.37886762]])

# %%
#model building
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 4.565230125523025

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([-8.82443400e-01,  8.84467711e+00,  1.46540728e+01, -1.03979470e+00,
#         3.98298018e+00, -2.53231323e+00,  8.34385906e+00,  2.21937617e+01,
#         1.02884763e+00,  1.73742233e+00,  1.49855359e+00, -9.71867882e-02,
#         8.10595189e+00,  3.42494291e+00,  1.63256684e+00,  4.05829972e+00,
#         6.72891454e+00,  6.90350211e-01,  8.19447911e+00,  2.37055610e+00,
#        -2.06625579e+00,  6.99315577e+00,  7.58105566e+00,  3.18001822e+00,
#         4.21517490e+00,  2.14652470e+00,  4.80302540e+00,  1.09321399e+00,
#         1.82372418e+00,  5.24370518e+00,  4.93633368e+01,  4.08160698e+00,
#         2.01650415e+00,  5.52823031e+00,  1.74025186e+00,  1.78569533e+01,
#         2.55105014e+00,  4.29758011e-01,  1.06661636e+01, -1.22397566e+00,
#         5.88171452e+00,  7.82166925e-01,  1.84387213e+00,  5.63352745e+00,
#         6.83301858e+00,  8.37875925e+00, -2.53216644e-02,  2.07311472e+00,
# ...

# %%
#importing metrics
from sklearn import metrics
metrics.mean_squared_error(y_test,y_pred)
# Out:
# 5.132840514763007

# %%
import statsmodels.api as sm
x_stats=sm.add_constant(x_train)
summ=sm.OLS(y_train, x_stats).fit()
summ.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          Selling_Price   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.855
# Method:                 Least Squares   F-statistic:                     176.5
# Date:                Mon, 23 Jan 2023   Prob (F-statistic):           1.14e-93
# Time:                        16:19:22   Log-Likelihood:                -468.00
# No. Observations:                 239   AIC:                             954.0
# Df Residuals:                     230   BIC:                             985.3
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.5652      0.113     40.379      0.000       4.342       4.788
# ...

# %%
#accuracy of model
model.score(x_test, y_test)
# Out:
# 0.8708986500692837

# %% [markdown]
# # random Forest Regressor

# %%
#model building
from sklearn.ensemble import RandomForestRegressor
model1=RandomForestRegressor()
model2=model1.fit(x_train,y_train)
model2
# Out:
# RandomForestRegressor()

# %%
y_pred=model2.predict(x_test)
y_pred
# Out:
# array([ 0.371 , 10.6569, 16.0862,  0.4213,  3.0925,  0.186 ,  9.232 ,
#        22.4533,  2.5465,  2.5685,  1.121 ,  1.0093,  7.5695,  3.109 ,
#         1.277 ,  4.1785,  6.5805,  1.0741,  8.3666,  1.2155,  0.1965,
#         7.1201,  6.1934,  3.123 ,  3.9975,  1.1456,  5.3765,  0.3724,
#         0.7898,  5.2855, 19.1955,  3.069 ,  0.7   ,  4.72  ,  0.726 ,
#        16.747 ,  2.7525,  0.7267,  8.5288,  0.2735,  4.3035,  0.3615,
#         0.4652,  6.2255,  5.117 ,  7.6145,  0.5309,  0.7534, 21.45  ,
#         0.2958,  2.4152,  2.919 ,  0.4607,  7.0685,  0.4781,  5.016 ,
#         0.2814,  6.528 ,  0.4386,  0.6436])

# %%
#accuracy of model
model2.score(x_test, y_test)
# Out:
# 0.8819607416382682
